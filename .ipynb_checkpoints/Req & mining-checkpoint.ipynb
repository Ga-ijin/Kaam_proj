# %%
# %load_ext sql
import psycopg2
from sqlalchemy import create_engine
import yaml
login = yaml.safe_load(open('logins.yml', 'r'))
login = login['postgres']
password=login['password']
db=login['db']
host="localhost"
port="5432"

engine = create_engine(f'postgresql://{user}:{password}@{host}:{port}/{db}')
dbConnection = engine.connect()
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# (psycopg2.OperationalError)
# (Background on this error at: http://sqlalche.me/e/13/e3q8)
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
df = pd.read_sql('select * from episode',engine)
df
# Out:
#     livre  num_ep                  titre_ep  \
# 0       1       1                      Heat
# 1       1       2  Les Tartes Aux Myrtilles
# 2       1       3       La Table De Breccan
# 3       1       4      Le Chevalier Mystère
# 4       1       5          Le Fléau De Dieu
# 5       1       6         Le Garde Du Corps
# 6       1       7    Des Nouvelles Du Monde
# 7       1       8       Codes Et Stratégies
# 8       1       9         Le Maître d’Armes
# 9       1      10            Le Négociateur
# 10      1      11             Dîner Dansant
# 11      1      12           Le Sixième Sens
# 12      1      13     Arthur Et La Question
# 13      1      14                  Monogame
# 14      1      15       Les Défis De Merlin
# 15      1      16      Le Banquet Des Chefs
# 16      1      17                  Le Signe
# 17      1      18         En Forme De Graal
# 18      1      19      Le Repos Du Guerrier
# 19      1      20         La Dent De Requin
# 20      1      21         La Taxe Militaire
# 21      1      22      La Queue Du Scorpion
# 22      1      23    La Potion De Fécondité
# 23      1      24              L’Interprète
# 24      1      25              Le Sacrifice
# 25      1      26              À La Volette
# 26      1      27        De Retour De Judée
# 27      1      28          La Botte Secrète
# 28      1      29   L’Assassin De Kaamelott
# 29      1      30          Le Trois De Cœur
# 30      1      31            Basidiomycètes
# 31      1      32               L’Imposteur
# 32      1      33    Compagnons De Chambrée
# 33      1      34      La Grotte De Padraig
# 34      1      35               Ambidextrie
# 35      1      36           Raison D’Argent
# 36      1      37    La Romance De Lancelot
# 37      1      38       Merlin Et Les Loups
# 38      1      39              Le Cas Yvain
# 39      1      40              L’Adoubement
# 40      1      41    Arthur Et Les Ténèbres
# 41      1      42              Le Zoomorphe
# 42      1      43   La Coccinelle De Madenn
# 43      1      44   Patience Dans La Plaine
# 44      1      45                    Le Oud
# 45      1      46     Le Code De Chevalerie
# 46      1      47                     Létal
# 47      1      48                    Azénor
# 48      1      49           Le Sort de Rage
# 49      1      50       Les Nouveaux Frères
#
#                                                script  \
# 0    A.Astier   3 CORS  1. EXT. TENTE DE COMMANDEM...
# 1    A.Astier   3 CORS  1. INT. SALLE À MANGER – J...
# 2    A.Astier   3 CORS  1. INT. COULOIRS – JOUR  A...
# 3    A.Astier   3 CORS  1. INT. SALLE DE LA TABLE ...
# 4    A.Astier   3 CORS  1. INT. COULOIRS – JOUR  A...
# 5    A.Astier   3 CORS  1. INT. SALLE DE LA TABLE ...
# 6    A.Astier   3 CORS  1. INT. SALLE À MANGER – J...
# 7    A.Astier   3 CORS  1. EXT. COLLINE DE COMMAND...
# 8    A.Astier   3 CORS  1. INT. CHAMBRE D’ARTHUR –...
# 9    A.Astier   3 CORS  1. INT. CHAMBRE D’ARTHUR –...
# 10   A.Astier   3 CORS  1. INT. SALLE À MANGER – S...
# 11   A.Astier   3 CORS  6. INT. TAVERNE – JOUR  PE...
# 12   A.Astier   3 CORS  1. INT. CHAMBRE D’ARTHUR –...
# 13   A.ASTIER   3 CORS  1. INT. TENTE DE SOINS – J...
# 14   F. RAULT – A.ASTIER   3 CORS  1. INT. LABORAT...
# 15   A.ASTIER   3 CORS  1. INT. CHAMBRE DE LÉODAGA...
# 16   F.RAULT-A.ASTIER   3 CORS  1. INT. CHAMBRE D’...
# 17   A.ASTIER   3 CORS  1. INT. TAVERNE – SOIR  PE...
# 18   A.ASTIER   3 CORS  1. INT. CHAMBRE DE DEMETRA...
# 19   A.ASTIER   3 CORS  1. INT. COULOIRS – JOUR  P...
# 20   A.ASTIER   3 CORS  1. INT. SALLE DU TRÔNE – J...
# 21   A.ASTIER   3 CORS  1. INT. CHAMBRE DE DEMETRA...
# 22   J.SEVILLA – A.ASTIER   3 CORS  1. INT. CHAMBR...
# 23   A.ASTIER   3 CORS  1. INT. SALLE DE BAINS – J...
# 24   A.ASTIER   3 CORS  1. INT. CHAMBRE D’ARTHUR –...
# 25   A.ASTIER   3 CORS  1. INT. SALLE À MANGER – J...
# 26   A.ASTIER   3 CORS  1. INT. COULOIRS – JOUR  A...
# 27   A.ASTIER   3 CORS  1. INT. TAVERNE – SOIR  PE...
# 28   A.ASTIER   3 CORS  1. INT. CHAMBRE D’ARTHUR –...
# 29   A.ASTIER   3 CORS  1. INT. SALLE DE BAINS – S...
# 30   A.ASTIER   3 CORS  1. INT. SALLE DE LA TABLE ...
# 31   A.ASTIER   3 CORS  1. INT. SALLE DU TRÔNE – J...
# 32   A.ASTIER   3 CORS  1. INT. SALLE À MANGER – J...
# 33   A.ASTIER   3 CORS  1. INT. SALLE À MANGER – J...
# 34   A.ASTIER   3 CORS  1. EXT. CAMPAGNE – JOUR  D...
# 35   A. ASTIER   3 CORS  1. INT. CHAMBRE DE LÉODAG...
# 36   A.ASTIER   3 CORS  1. INT. SALLE DE BAIN – JO...
# 37   A.ASTIER   3 CORS  1. EXT. FORÊT – CRÉPUSCULE...
# 38   A.ASTIER   3 CORS  1. INT. CHAMBRE D’YVAIN – ...
# 39   F.RAULT – A.ASTIER   3 CORS  1. INT. SALLE DU...
# 40   A.ASTIER   3 CORS  1. INT. SALLE À MANGER – J...
# 41   A.ASTIER   3 CORS  1. INT. LABORATOIRE DE MER...
# 42   A.ASTIER   3 CORS  1. INT. COULOIRS – JOUR  A...
# 43   A.ASTIER   3 CORS  1. EXT. ENCEINTE DU CHÂTEA...
# 44   A.ASTIER   3 CORS  1. EXT. FORÊT – JOUR  LANC...
# 45   F.RAULT – A.ASTIER   3 CORS  1. EXT. FORÊT – ...
# 46   A.ASTIER   3 CORS  1. INT. CHAMBRE D’ARTHUR —...
# 47   A.ASTIER   3 CORS  1. INT. COULOIRS – JOUR  A...
# 48   A.ASTIER   3 CORS  1. EXT. CRÉNEAUX – JOUR  A...
# 49   A.ASTIER   3 CORS  1. INT. CHAMBRE D’YVAIN – ...
#
#                                             resume_vf  \
# 0    Arthur, Léodagan et Perceval sont isolés en f...
# 1    Séli a cuisiné une tarte aux myrtilles qui s’...
# 2    Un artisan vient de livrer une table ronde co...
# 3    Autour de la Table ronde flambant neuve, les ...
# 4    Arthur, Léodagan et Bohort doivent négocier f...
# 5    Un traité de paix est sur le point d’être sig...
# 6    Guenièvre et sa mère ont convoqué un barde au...
# 7    Arthur et ses chevaliers dirigent une bataill...
# 8    Arthur se fait entrainer par son maître d’arm...
# 9    Des barbares sont aux portes du domaine, et A...
# 10   C’est le dîner de famille avec Léodagan, son ...
# 11   Karadoc et Perceval sont convoqués à la Table...
# 12   Un voleur nargue l’autorité du roi en refusan...
# 13   Le Répurgateur vient soumettre au roi une nou...
# 14   Elias de Kelliwic’h, enchanteur de Calédonie,...
# 15   À Kaamelott, on prépare le banquet des chefs ...
# 16   Un corbeau mort est retrouvé devant la porte ...
# 17   Lors de la réunion de la Table ronde, Bohort ...
# 18   Demetra, Perceval et Guenièvre reprochent à A...
# 19   Perceval et Karadoc ont été envoyés chez Merl...
# 20   Le seigneur Jacca, que Léodagan croyait mort,...
# 21   L’empereur romain a été assassiné par un scor...
# 22   Dans l’espoir de faire naitre un héritier, Sé...
# 23   Arthur doit signer un traité avec les Burgond...
# 24   Le château est en proie aux hurlements des lo...
# 25   Guenièvre a invité un ménestrel pendant le re...
# 26   Le chevalier Dagonet est de retour d’une miss...
# 27   Quand Karadoc ne comprend pas un mot, et qu’i...
# 28   Bohort est terrifié : plusieurs servants ont ...
# 29   Arthur se sent très mal à l’aise de devoir pa...
# 30   Quelques heures avant un assaut, a priori gag...
# 31   Arthur a de sérieux doutes sur Merlin, et le ...
# 32   Alors que Guenièvre est partie en voyage, Art...
# 33   La Dame du Lac confie une mission à Arthur : ...
# 34   Perceval a de sérieux problèmes pour distingu...
# 35   Alors que les caisses sont vides, Venec propo...
# 36   Lancelot, confident de la reine, est aussi se...
# 37   Les envahisseurs sont en marche. Arthur, Léod...
# 38   Yvain, fils de Léodagan et de Séli, est un je...
# 39   Arthur s’aperçoit que Perceval n’a jamais été...
# 40   Séli confie un secret à Léodagan : Arthur a p...
# 41   Merlin, en tant qu’enchanteur, possède la fac...
# 42   Guethenoc accuse, en séance de doléances, le ...
# 43   Arthur et ses hommes sont sur le champ de bat...
# 44   Perceval récupère un oud sur un camp égyptien...
# 45   Le père Blaise et Léodagan ont traduit le cod...
# 46   Arthur souhaiterait abolir la peine de mort e...
# 47   Lors d’un banquet, Arthur a repéré une jeune ...
# 48   Arthur est las de voir ses hommes se battre m...
# 49   Yvain et Gauvain sont réunis par Arthur en un...
#
#                                             resume_va  ep_id
# 0   Stuck in the forest during a battle, King Arth...      1
# 1   Arthur, Guinevere and Leodagan are forced to e...      2
# 2   The round table ordered by King Arthur has arr...      3
# 3   King Arthur and The Knights of the Round Table...      4
# 4   King Arthur, Léodagan and Bohort negotiate wit...      5
# 5   King Arthur is close to sign a peace treaty an...      6
# 6   A barb invited to dinner sings odes far from a...      7
# 7   King Arthur and his knights are sending signal...      8
# 8   King Arthur is training with his fencing maste...      9
# 9   Kaamelott is under attack and Bohort has made ...     10
# 10  A family diner at Kaamelott, where everyone wa...     11
# 11  King Arthur has Summoned Perceval and Karadoc ...     12
# 12  Léodagan has failed to get a thief to talk. He...     13
# 13         King Arthur refuses to oulaw polygamy.         14
# 14  A foreign wizard defies Merlin over the owners...     15
# 15  Everyone is helping with the upcoming festivit...     16
# 16  A dead crow is found in front of the King's do...     17
# 17  The knights of the Round Table enter a heated ...     18
# 18  The King is subject to criticism for having hi...     19
# 19  During a battle Merlin needs a shark tooth for...     20
# 20  A presumed dead nobleman arrives at Camelot to...     21
# 21  Grüdu hears that the Roman Emperor was assassi...     22
# 22  Desperate to get an heir, Seli gets a fertilit...     23
# 23  The Burgundian king brings an interpreter (Lor...     24
# 24                                               None     25
# 25  Arthur can't get that song out of his head-eve...     26
# 26  Dagonet returns from the Holy Land with souven...     27
# 27  Karadoc teaches Perceval a "secret move" in co...     28
# 28                                               None     29
# 29  Arthur has to share a bed with Demetra and Gue...     30
# 30  Problems with a mushroom omelette on the battl...     31
# 31  Arthur, returning from a trip, is surprised to...     32
# 32  Arthur, returning from a trip, is surprised to...     33
# 33  A quest from the Lady of the Lake to kill a mo...     34
# 34  Perceval, when being briefed on a battle plan,...     35
# 35                                               None     36
# 36                                               None     37
# 37                                               None     38
# 38                                               None     39
# 39                                               None     40
# 40                                               None     41
# 41                                               None     42
# 42                                               None     43
# 43                                               None     44
# 44                                               None     45
# 45                                               None     46
# 46                                               None     47
# 47                                               None     48
# 48                                               None     49
# 49                                               None     50

# %%
# %sql postgresql://postgres:8774755@localhost/kaam_db2
# %%sql SELECT * FROM episode
